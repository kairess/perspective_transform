# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/visualcamp/Development/tf/GazeCapture/dataset/adience/faces/10062073@N07/coarse_tilt_aligned_face.2249.8727652715_4dd41400a4_o.jpg')

plt.imshow(img)

# %%
src = np.array([
    [-30, 30],
    [460, -30],
    [520, 460],
    [30, 520]
], dtype=np.float32)

width = max(np.linalg.norm(src[0] - src[1]), np.linalg.norm(src[2] - src[3]))
height = max(np.linalg.norm(src[0] - src[3]), np.linalg.norm(src[1] - src[2]))

dst = np.array([
    [0, 0],
    [width, 0],
    [width, height],
    [0, height]
], dtype=np.float32)

M = cv2.getPerspectiveTransform(src, dst)
M
# Out:
# array([[ 9.92586365e-01, -1.21541188e-01,  3.34238266e+01],
#        [ 1.21541188e-01,  9.92586365e-01, -2.61313553e+01],
#        [-1.80138595e-19, -2.71684430e-19,  1.00000000e+00]])

# %%
warped = cv2.warpPerspective(img, M, (width, height))

plt.imshow(warped)
